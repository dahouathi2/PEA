# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
berages = pd.read_csv("dataset/others.csv")

# %%
berages.head()
# Out:
#    family        date         sales
# 0  OTHERS  2013-01-01    672.618999
# 1  OTHERS  2013-01-02  98777.254934
# 2  OTHERS  2013-01-03  90584.231124
# 3  OTHERS  2013-01-04  94326.677093
# 4  OTHERS  2013-01-05  92584.821204

# %%
plt.plot(berages["sales"])

# %%
combined_dataframes = pd.read_csv('./dataset/true_promo_data_77.csv')

# %%
product_index=12
data = combined_dataframes[77*product_index:77*(product_index+1)].reset_index()

# %%
plt.plot(data["sold_units"])
